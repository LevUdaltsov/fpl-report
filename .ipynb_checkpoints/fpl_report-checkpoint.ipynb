# %%
import requests
import json

import pandas as pd
from fpdf import FPDF
import seaborn as sns

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt


pd.options.plotting.backend = "plotly"

fpl_id = 2024013
current_gw = 26

def get(url):
    response = requests.get(url)
    return json.loads(response.content)

def get_team_data(fpl_id, current_gw):

    my_team_url = 'https://fantasy.premierleague.com/' +\
        'api/entry/{}/event/{}/picks/'.format(fpl_id, current_gw)
    my_team = get(my_team_url)
    return my_team

def get_season_data():
    
    season_data = {}
    for gw in range(1, 38):
        week_label = 'week_%s'  % (gw)
        
        try:
            team_data = get_team_data(fpl_id, gw)
            team_data['entry_history']['active_chip'] = team_data['active_chip']
            team_data['entry_history']['automatic_subs'] = team_data['automatic_subs']
            team_data['entry_history']['picks'] = team_data['picks']
            season_data[week_label] = team_data['entry_history']
        except:
            print('no data for gameweek %f' % (int(gw)))
            

    return season_data

def create_df(data):
    fpl_df = pd.DataFrame.from_dict(data, 'index')
    fpl_df.rename(columns={'event': 'gameweek'}, inplace=True)
    fpl_df.index = pd.Index(fpl_df['gameweek'])
    fpl_df.drop(['gameweek'], axis=1, inplace=True)
    
    return fpl_df


def create_plot(fpl_df):
    
    sns.set_theme()
    sns.set_style("dark")
    fig, ax1 = plt.subplots(figsize=(12,8))
    font = fm.FontProperties(fname='RadikalBold.ttf')
    
    plt.ticklabel_format(style='plain', axis='both', scilimits=(0,0))
    
    g = sns.lineplot(data=fpl_df['overall_rank'], linewidth=3, color="r", ax=ax1)
    ax2 = plt.twinx()
    plt.ticklabel_format(style='plain', axis='both', scilimits=(0,0))
    g2 = sns.lineplot(data=fpl_df['rank'], linewidth=3, color="b", ax=ax2)
    ylabels = ['{}'.format(x) + 'M' for x in g.get_yticks()/1000000]
    g.set_yticklabels(ylabels)
    ylabels2 = ['{}'.format(x) + 'M' for x in g2.get_yticks()/1000000]
    g2.set_yticklabels(ylabels2)
    ax1.set_ylabel('Overall Rank', fontproperties=font, fontsize=18)
    ax2.set_ylabel('Gameweek Rank', fontproperties=font, fontsize=18)
    ax2.set_xlabel('Gameweek', fontproperties=font, fontsize=18)
    ax1.set_xlabel('Gameweek', fontproperties=font, fontsize=18)
    
    h1, l1 = ax1.get_legend_handles_labels()
    h2, l2 = ax2.get_legend_handles_labels()
    ax1.legend(h1+h2, l1+l2)
    
    plt.savefig('fig1.png', dpi=300)
    



def create_report(fpl_id, current_gw):
    
    data = get_team_data(fpl_id, current_gw)
    
    
    pdf = FPDF('L', 'pt', 'A4')
    pdf.add_page()

    # Add background image
    pdf.image('base_image.png', 0, 0, w=842)

    # Font settings
    pdf.set_text_color(255, 255, 255)
    pdf.add_font('RadikalBold', '', 'RadikalBold.ttf', uni=True)
    pdf.set_font('RadikalBold', '', 16)
    pdf.set_font_size(12)
    
    # Print rank
    
    team_name = 'De Bruynevirus'
    rank = data['entry_history']['overall_rank']
    score = data['entry_history']['total_points']
                                  
    
    
    pdf.set_xy(100, 185)
    pdf.cell(2, txt='Team Name:    %s' %(team_name))
    
    pdf.set_xy(100, 200)
    pdf.cell(2, txt='Total Points:    %s' %(score))
    
    pdf.set_xy(100, 215)
    pdf.cell(2, txt='Overall Rank:    %s' %(rank))
    
    pdf.image('fig1.png', 100, 310, w=300)
                                  
    
    
    
    pdf.output('report.pdf', 'F')

# %%
data = get_season_data()
fpl_df = create_df(data)
create_plot(fpl_df)
create_report(fpl_id, current_gw)
# Out:
# no data for gameweek 28.000000
# no data for gameweek 29.000000
# no data for gameweek 30.000000
# no data for gameweek 31.000000
# no data for gameweek 32.000000
# no data for gameweek 33.000000
# no data for gameweek 34.000000
# no data for gameweek 35.000000
# no data for gameweek 36.000000
# no data for gameweek 37.000000
# <ipython-input-18-b63a38c488aa>:69: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_yticklabels(ylabels)
# <ipython-input-18-b63a38c488aa>:71: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g2.set_yticklabels(ylabels2)
